# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\GEOSCIENCE_DATA_ANALYSIS'

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'field_notes.txt',
#  'Freeman-001.las',
#  'logs.csv',
#  'Untitled.ipynb',
#  'untitled.txt',
#  'Untitled1.ipynb',
#  'untitled1.txt']

# %%
import lasio
las = lasio.read("Freeman-001.las")

# %%
import lasio

las = lasio.read("Freeman-001.las")

# %%
las.curves
# Out:
# [CurveItem(mnemonic="DEPT", unit="F", value="FT. MD                            00 001 00 00", descr="1  DEPTH", original_mnemonic="DEPT", data.shape=(19991,)),
#  CurveItem(mnemonic="DEN", unit="G/CC", value="", descr="2  Bulk Density", original_mnemonic="DEN", data.shape=(19991,)),
#  CurveItem(mnemonic="DT", unit="US/F", value="", descr="3  Sonic (Compressional)         Compressional sonic", original_mnemonic="DT", data.shape=(19991,)),
#  CurveItem(mnemonic="GR", unit="API", value="", descr="4  Gamma Ray", original_mnemonic="GR", data.shape=(19991,)),
#  CurveItem(mnemonic="NEUT", unit="FRAC", value="", descr="5  Neutron Porosity", original_mnemonic="NEUT", data.shape=(19991,)),
#  CurveItem(mnemonic="RES_DEP", unit="OHMM", value="", descr="6  Resistivity Deep              Deep resistivity. RSN_01<5433> ATR_J <65", original_mnemonic="RES_DEP", data.shape=(19991,))]
